# %%
# here is how we activate an environment in our current directory
import Pkg; Pkg.activate(@__DIR__); Pkg.add("CircleFit"); Pkg.add("StatsBase");

# instantate this environment (download packages if you haven't)
Pkg.instantiate();

using Test, LinearAlgebra
import ForwardDiff as FD 
import FiniteDiff as FD2 
using CircleFit
using Plots
using StatsBase
import Convex as cvx
import ECOS
# Out:
#   Activating project at `~/Downloads/MSR Academics/zoe2_optimal_controller/julia`
#    Resolving package versions...
#    Installed DataStructures ─────────── v0.18.22
#    Installed FreeType2_jll ──────────── v2.13.4+0
#    Installed NLSolversBase ──────────── v7.9.0
#    Installed ADTypes ────────────────── v1.14.0
#    Installed OffsetArrays ───────────── v1.16.0
#    Installed Cairo_jll ──────────────── v1.18.4+0
#    Installed UnsafeArrays ───────────── v1.0.7
#    Installed JLD2 ───────────────────── v0.5.12
#    Installed JLFzf ──────────────────── v0.1.10
#    Installed Pixman_jll ─────────────── v0.44.2+0
#    Installed URIs ───────────────────── v1.5.2
#    Installed GeometryBasics ─────────── v0.5.7
#    Installed Plots ──────────────────── v1.40.11
#    Installed DocStringExtensions ────── v0.9.4
#    Installed Ipopt ──────────────────── v1.8.0
#    Installed DifferentiationInterface ─ v0.6.49
#     Updating `~/Downloads/MSR Academics/zoe2_optimal_controller/julia/Project.toml`
#   [a2741ea9] + CircleFit v0.2.5
#     Updating `~/Downloads/MSR Academics/zoe2_optimal_controller/julia/Manifest.toml`
#   [47edcb42] + ADTypes v1.14.0
#   [7d9f7c33] + Accessors v0.1.42
#   [a2741ea9] + CircleFit v0.2.5
#   [38540f10] + CommonSolve v0.2.4
#   [a33af91c] + CompositionsBase v0.1.2
#   [a0c0ee7d] + DifferentiationInterface v0.6.49
#   [31c24e10] + Distributions v0.25.118
#   [1a297f60] + FillArrays v1.13.0
#   [34004b35] + HypergeometricFunctions v0.3.28
#   [3587e190] + InverseFunctions v0.1.17
#   [2fda8390] + LsqFit v0.15.0
#   [d41bc354] + NLSolversBase v7.9.0
#   [90014a1f] + PDMats v0.11.32
#   [1fd47b50] + QuadGK v2.11.2
#   [79098fc4] + Rmath v0.8.0
#   [f2b01f46] + Roots v2.2.6
#   [4c63d2b9] + StatsFuns v1.3.2
#   [f50d1b31] + Rmath_jll v0.5.1+0
#   [4607b0f0] + SuiteSparse
#   [05823500] ↓ OpenLibm_jll v0.8.1+4 ⇒ v0.8.1+2
# Precompiling project...
#   ✓ ADTypes
#   ✓ UnsafeArrays
#   ✓ OffsetArrays
#   ✓ DocStringExtensions
#   ✓ URIs
#   ✓ Pixman_jll
#   ✓ FreeType2_jll
#   ✓ StaticArrays → StaticArraysChainRulesCoreExt
#   ✓ DataStructures
#   ✓ JLFzf
#   ✓ LightXML
#   ✓ Widgets
#   ✓ Accessors → StaticArraysExt
#   ✓ ADTypes → ADTypesConstructionBaseExt
#   ✓ ADTypes → ADTypesChainRulesCoreExt
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ✓ LogExpFunctions
#   ✓ Roots → RootsChainRulesCoreExt
#   ✓ SortingAlgorithms
#   ✓ QuadGK
#   ✓ DifferentiationInterface
#   ✓ Fontconfig_jll
#   ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#   ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#   ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ RigidBodyDynamics
#   ✓ DifferentiationInterface → DifferentiationInterfaceSparseArraysExt
#   ✓ GeometryBasics
#   ✓ Qt6Base_jll
#   ✓ SpecialFunctions
#   ✓ Interpolations
#   ✓ Cairo_jll
#   ✓ StatsBase
#   ✓ HTTP
#   ✓ Qt6ShaderTools_jll
#   ✓ MechanismGeometries
#   ✓ ColorVectorSpace → SpecialFunctionsExt
#   ✓ Interpolations → InterpolationsUnitfulExt
#   ✓ FileIO → HTTPExt
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ WebSockets
#   ✓ Qt6Declarative_jll
#   ✓ HypergeometricFunctions
#   ✓ HarfBuzz_jll
#   ✓ ColorSchemes
#   ✓ libass_jll
#   ✓ Pango_jll
#   ✓ ForwardDiff
#   ✓ WebIO
#   ✓ StatsFuns
#   ✓ FFMPEG_jll
#   ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#   ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   ✓ Roots → RootsForwardDiffExt
#   ✓ CSSUtil
#   ✓ StatsFuns → StatsFunsInverseFunctionsExt
#   ✓ JSExpr
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   ✓ PlotUtils
#   ✓ NLSolversBase
#   ✓ Knockout
#   ✓ GR
#   ✓ PlotThemes
#   ✓ MeshCat
#   ✓ RecipesPipeline
#   ✓ InteractBase
#   ✓ Distributions
#   ✓ JLD2
#   ✓ Distributions → DistributionsTestExt
#   ✓ Distributions → DistributionsChainRulesCoreExt
#   ✓ MeshCatMechanisms
#   ✓ LsqFit
#   ✓ CircleFit
#   ✓ MathOptInterface
#   ✓ ECOS
#   ✓ Convex
#   ✓ Ipopt
#   ✓ Plots
#   ✓ Plots → UnitfulExt
#   ✓ Plots → FileIOExt
#   ✓ Plots → GeometryBasicsExt
#   85 dependencies successfully precompiled in 172 seconds. 218 already precompiled.
#   1 dependency had output during precompilation:
# ┌ MeshCat
# │  [ Info: Listening on: 127.0.0.1:8700, thread id: 1
# │  ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# │  └ http://127.0.0.1:8700
# │  [ Info: Server on 127.0.0.1:8700 closing
# │  [ Info: MeshCat server closed.
# └
#    Resolving package versions...
#     Updating `~/Downloads/MSR Academics/zoe2_optimal_controller/julia/Project.toml`
#   [2913bbd2] + StatsBase v0.34.4
#   No Changes to `~/Downloads/MSR Academics/zoe2_optimal_controller/julia/Manifest.toml`
# [ Info: Precompiling IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a]

# %%
function dynamics(params::NamedTuple, x::Vector, u::Vector)
    x_pos, y_pos, ϕ = x[1:3]  # States
    ω_fl, ω_fr, ω_rl, ω_rr = u[1:4]  # Inputs
    r, L, B = params.r, params.L, params.B

    ϵ = 1e-6
    # R = (L/4)*((1/(tan(f_steerθ)+ϵ))+(1/(tan(r_steerθ)+ϵ)))
    V_l = (r/2)*(ω_fl+ω_rl)
    V_r = (r/2)*(ω_fr+ω_rr)
    R = (L/2)*(V_l+V_r)/(V_r-V_l+ϵ)
    f_steerθ = atan(L/(2*R+ϵ))
    r_steerθ = atan(L/(2*R+ϵ))

    # Rfl = (L-B*sin(f_steerθ))/(2*sin(f_steerθ)+ϵ)
    # Rfr = (L+B*sin(f_steerθ))/(2*sin(f_steerθ)+ϵ)
    # Rrl = (L-B*sin(r_steerθ))/(2*sin(r_steerθ)+ϵ)
    # Rrr = (L+B*sin(r_steerθ))/(2*sin(r_steerθ)+ϵ)
    # v = ((R*r)/4)*((ω_fl/Rfl)+ (ω_fr/Rfr)+ (ω_rl/Rrl) + (ω_rr/Rrr))

    v = (r/4)*((ω_fl/cos(f_steerθ))+ (ω_fr/cos(f_steerθ))+ (ω_rl/cos(r_steerθ)) + (ω_rr/cos(r_steerθ)))

    xdot = [v*cos(ϕ); v*sin(ϕ); v/(R+ϵ)]
    
    return xdot
end

function rk4(params::NamedTuple, x::Vector,u,dt::Float64)
    # vanilla RK4
    k1 = dt*dynamics(params, x, u)
    k2 = dt*dynamics(params, x + k1/2, u)
    k3 = dt*dynamics(params, x + k2/2, u)
    k4 = dt*dynamics(params, x + k3, u)
    return x + (1/6)*(k1 + 2*k2 + 2*k3 + k4)
end
# Out:
# rk4 (generic function with 1 method)

# %%
params = (r = 0.325, L = 1.91, B = 1.64)
u = [1.5, 1.5, 1.5, 1.5]

x0 = [0,0,pi/2]
nx = 3
N = 1001
dt = 1.0
t_vec = 0:dt:((N-1)*dt)

X = [zeros(nx) for i = 1:N]
X[1] = x0
for i = 1:(N-1)
    X[i+1] = rk4(params, X[i], u, dt)
end

X = hcat(X...)
x = X[1,:]
y = X[2,:]
print(y[2]-y[1])
# result = fit(Circle,x,y)
# @show coef(result)
# @show coefnames(result)
# @show rss(result)

display(scatter(X[1,:]', X[2,:]', legend=false, aspect_ratio=:equal))
# Out:
# 0.4875000000002343

# %%
### Traj Loading
function create_reference()
    # create reference trajectory for quadrotor 
    X_ref = [zeros(3) for i = 1:80]

    open("/Users/morganmayborne/Downloads/spline_test.txt") do f
        line = 1
        while !eof(f)
            x = readline(f)
            x, y = split(x, ',')
            X_ref[line] = [parse(Float64, x),parse(Float64, y), pi/4]
            line += 1
        end
    end
    U_ref = [zeros(4) for i = 1:(size(X_ref)[1]-1)]
    return X_ref, U_ref;
end
# Out:
# create_reference (generic function with 2 methods)

# %%
"""
`u = convex_mpc(A,B,X_ref_window,xic,xg,u_min,u_max,N_mpc)`

setup and solve the above optimization problem, returning the 
first control u_1 from the solution (should be a length nu 
Vector{Float64}).  
"""
function convex_mpc(A::Matrix, # discrete dynamics matrix A
                    B::Matrix, # discrete dynamics matrix B
                    X_ref_window::Vector{Vector{Float64}}, # reference trajectory for this window 
                    xic::Vector, # current state x 
                    u_min::Vector, # lower bound on u 
                    u_max::Vector, # upper bound on u 
                    N_mpc::Int64,  # length of MPC window (horizon)
                    )::Vector{Float64} # return the first control command of the solved policy 
    
    # get our sizes for state and control
    nx,nu = size(B)
    
    # check sizes 
    @assert size(A) == (nx, nx)
    @assert length(xic) == nx 
    @assert length(xg) == nx 
    @assert length(X_ref_window) == N_mpc 
        
    # LQR cost
    Q = diagm([ones(nx-1);1e-3*ones(1)])
    R = .001*diagm(ones(nu))
    Qf = 10*Q

    P = [zeros(nx,nx) for i = 1:N_mpc]
    K = [zeros(nu,nx) for i = 1:N_mpc-1]

    P[end] = deepcopy(Qf)
    
    for k = (N_mpc-1):-1:1
        K[k] = (R+B'*P[k+1]*B)\(B'*P[k+1]*A)
        P[k] = Q + A'*P[k+1]*(A-B*K[k])
    end
    
    # simulation 
    X_s = [zeros(nx) for i = 1:N_mpc]
    U_s = [zeros(nu) for i = 1:N_mpc-1]
    X_s[1] = xic
    @show X_s[1]
    @show X_ref_window[1]
    @show K[1]
    
    for i = 1:(N_mpc-1) 
        # TODO: put LQR control law here 
        # make sure to clamp 
        U_s[i] = clamp.(-K[i]*(X_s[i]-X_ref_window[i])+1e-6*ones(4), u_min, u_max)
        
        # simulate 1 step 
        X_sim[i+1] = A*X_s[i] + B*U_s[i]
    end
    @show U_s[1]
    println()
    return U_s[1]
end
        

# create our discrete time model 
dt = 0.5

X_ref, _ = create_reference()

# initial and goal states
x0 = deepcopy(X_ref[1])
xg = deepcopy(X_ref[80])

# bounds on U
u_max = 2*ones(4)
u_min = -u_max

# problem size and reference trajectory 
N = 80 
t_vec = 0:dt:((N-1)*dt)
params = (r = 0.325, L = 1.91, B = 1.64)

# MPC window size 
N_mpc = 20 
X_ref = vcat(X_ref, [xg for i = 1:(2*N_mpc)])

# sim size and setup 
N_sim = N + 20 
t_vec = 0:dt:((N_sim-1)*dt)
X_sim = [zeros(3) for i = 1:N_sim]
X_sim[1] = x0 
U_sim = [1e-6*ones(4) for i = 1:N_sim-1]

# simulate 
for i = 1:N_sim-1 
    # TODO: given a window of N_mpc timesteps, get current reference trajectory
    X_ref_tilde = X_ref[i:i+N_mpc-1]
    A = FD.jacobian(_x -> rk4(params, _x, U_sim[i], dt), X_sim[i])
    B = FD.jacobian(_u -> rk4(params, X_sim[i], _u, dt), U_sim[i])
    
    nx, nu = size(B)
    discrete = exp([A B; zeros(nu,nx+nu)]*dt)
    A = discrete[1:nx,1:nx] # TODO 
    B = discrete[1:nx,(nx+1):end] # TODO 
    
    # TODO: call convex mpc controller with state estimate 
    u_mpc = convex_mpc(A, B, X_ref_tilde, X_sim[i],u_min, u_max, N_mpc)
    
    # commanded control goes into thruster model where it gets modified 
    U_sim[i] = deepcopy(u_mpc)
    
    # simulate one step 
    X_sim[i+1] = A*X_sim[i] + B*U_sim[i]
    
    X_sim[i+1][3] = rem(X_sim[i+1][3], 2π)
    if X_sim[i+1][3] < 0
        X_sim[i+1][3] += 2π
    end
end

print(X_sim[80])
# Out:
# X_s[1] = [0.0, 0.0, 0.785]
# X_ref_window[1] = [0.0, 0.0, 0.785]
# K[1] = [-87.16529045024973 101.12713372521023 23.463053714747033; 159.92757603720003 -128.15062830583037 -141.60495677231964; -87.16529045024971 101.12713372521024 23.463053714747062; 159.92757603719997 -128.15062830583037 -141.60495677231967]
# U_s[1] = [1.0e-6, 1.0e-6, 1.0e-6, 1.0e-6]
#
# X_s[1] = [5.663022845236817e-9, 1.7384051772583907e-7, 1.2942462097706253]
# X_ref_window[1] = [0.07931185303980172, 0.08601837002478495, 0.785]
# K[1] = [-125.40651062813151 45.800583934859915 23.46305371477993; 202.1106217849991 -33.922111941573064 -141.60495677231955; -125.40651062813146 45.800583934859894 23.463053714779907; 202.1106217849991 -33.92211194157307 -141.60495677231953]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [-0.13135072967018968, -0.46278877126496737, 3.40470892841012]
# X_ref_window[1] = [0.20790202653448023, 0.2103076250182242, 0.785]
# K[1] = [25.148701090736708 -131.11837750830603 23.4630537147758; -74.75340096671646 190.81756269331254 -141.6049567723199; 25.148701090736708 -131.11837750830608 23.463053714775796; -74.75340096671646 190.81756269331248 -141.60495677231987]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [0.020663844749259586, 0.005566034200360802, 0.0062377181522111635]
# X_ref_window[1] = [0.37964717888905086, 0.36958740341157603, 0.785]
# K[1] = [8.98878337687123 133.20543531493024 23.46305371477739; 23.820933226301836 -203.54846161704555 -141.6049567723188; 8.988783376871229 133.20543531493018 23.46305371477739; 23.82093322630183 -203.54846161704552 -141.60495677231881]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.4810591412206314, 0.0030008440563516954, 0.11341702516136373]
# X_ref_window[1] = [0.588423968508529, 0.5605773436360986, 0.785]
# K[1] = [-5.312344031286729 133.40264317108688 23.4630537147769; 45.45868229939436 -199.8322328405234 -141.60495677231867; -5.312344031286733 133.4026431710869 23.463053714776915; 45.45868229939437 -199.83223284052337 -141.60495677231867]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.4779777119640005, 0.05444455236881671, 0.11341702516136373]
# X_ref_window[1] = [0.8281090537979297, 0.7799970841230499, 0.785]
# K[1] = [-5.312344031286729 133.40264317108688 23.4630537147769; 45.45868229939436 -199.8322328405234 -141.60495677231867; -5.312344031286733 133.4026431710869 23.463053714776915; 45.45868229939437 -199.83223284052337 -141.60495677231867]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.4779777119640005, 0.05444455236881671, 0.11341702516136373]
# X_ref_window[1] = [1.0925790931622685, 1.0245662633036885, 0.785]
# K[1] = [-5.312344031286729 133.40264317108688 23.4630537147769; 45.45868229939436 -199.8322328405234 -141.60495677231867; -5.312344031286733 133.4026431710869 23.463053714776915; 45.45868229939437 -199.83223284052337 -141.60495677231867]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.4779777119640005, 0.05444455236881671, 0.11341702516136373]
# X_ref_window[1] = [1.3757107450065604, 1.2910045196092725, 0.785]
# K[1] = [-5.312344031286729 133.40264317108688 23.4630537147769; 45.45868229939436 -199.8322328405234 -141.60495677231867; -5.312344031286733 133.4026431710869 23.463053714776915; 45.45868229939437 -199.83223284052337 -141.60495677231867]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.4779777119640005, 0.05444455236881671, 0.11341702516136373]
# X_ref_window[1] = [1.6713806677358212, 1.5760314914710598, 0.785]
# K[1] = [-5.312344031286729 133.40264317108688 23.4630537147769; 45.45868229939436 -199.8322328405234 -141.60495677231867; -5.312344031286733 133.4026431710869 23.463053714776915; 45.45868229939437 -199.83223284052337 -141.60495677231867]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.4779777119640005, 0.05444455236881671, 0.11341702516136373]
# X_ref_window[1] = [1.9734655197550661, 1.8763668173203087, 0.785]
# K[1] = [-5.312344031286729 133.40264317108688 23.4630537147769; 45.45868229939436 -199.8322328405234 -141.60495677231867; -5.312344031286733 133.4026431710869 23.463053714776915; 45.45868229939437 -199.83223284052337 -141.60495677231867]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.4779777119640005, 0.05444455236881671, 0.11341702516136373]
# X_ref_window[1] = [2.27584195946931, 2.188730135588278, 0.785]
# K[1] = [-5.312344031286729 133.40264317108688 23.4630537147769; 45.45868229939436 -199.8322328405234 -141.60495677231867; -5.312344031286733 133.4026431710869 23.463053714776915; 45.45868229939437 -199.83223284052337 -141.60495677231867]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.4779777119640005, 0.05444455236881671, 0.11341702516136373]
# X_ref_window[1] = [2.5723866452835686, 2.5098410847062254, 0.785]
# K[1] = [-5.312344031286729 133.40264317108688 23.4630537147769; 45.45868229939436 -199.8322328405234 -141.60495677231867; -5.312344031286733 133.4026431710869 23.463053714776915; 45.45868229939437 -199.83223284052337 -141.60495677231867]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.5091823203986063, 0.05799894265251162, 0.10545971942392782]
# X_ref_window[1] = [2.856976235602857, 2.8364193031054086, 0.785]
# K[1] = [-4.250661429069721 133.44069122899452 23.463053714777352; 43.86713372638992 -200.1876311722516 -141.60495677231916; -4.250661429069728 133.4406912289946 23.463053714777367; 43.86713372638993 -200.18763117225163 -141.60495677231916]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.596671692420519, 0.06315925482606341, 0.08328253850728595]
# X_ref_window[1] = [3.123487388832191, 3.165184429217086, 0.785]
# K[1] = [-1.2905204070967897 133.50213767263725 23.46305371477716; 39.41711323779116 -201.11117393475536 -141.60495677231867; -1.2905204070967913 133.50213767263733 23.463053714777168; 39.41711323779117 -201.11117393475539 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.5979255481115988, 0.04991231232465597, 0.08328253850728595]
# X_ref_window[1] = [3.3657967633765855, 3.4928561014725172, 0.785]
# K[1] = [-1.2905204070967897 133.50213767263725 23.46305371477716; 39.41711323779116 -201.11117393475536 -141.60495677231867; -1.2905204070967913 133.50213767263733 23.463053714777168; 39.41711323779117 -201.11117393475539 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.5979255481115988, 0.04991231232465597, 0.08328253850728595]
# X_ref_window[1] = [3.577781017641056, 3.8161539583029604, 0.785]
# K[1] = [-1.2905204070967897 133.50213767263725 23.46305371477716; 39.41711323779116 -201.11117393475536 -141.60495677231867; -1.2905204070967913 133.50213767263733 23.463053714777168; 39.41711323779117 -201.11117393475539 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.5979255481115988, 0.04991231232465597, 0.08328253850728595]
# X_ref_window[1] = [3.7533168100306167, 4.13179763813967, 0.785]
# K[1] = [-1.2905204070967897 133.50213767263725 23.46305371477716; 39.41711323779116 -201.11117393475536 -141.60495677231867; -1.2905204070967913 133.50213767263733 23.463053714777168; 39.41711323779117 -201.11117393475539 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.5979255481115988, 0.04991231232465597, 0.08328253850728595]
# X_ref_window[1] = [3.8862807989502843, 4.436506779413908, 0.785]
# K[1] = [-1.2905204070967897 133.50213767263725 23.46305371477716; 39.41711323779116 -201.11117393475536 -141.60495677231867; -1.2905204070967913 133.50213767263733 23.463053714777168; 39.41711323779117 -201.11117393475539 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.5979255481115988, 0.04991231232465597, 0.08328253850728595]
# X_ref_window[1] = [3.970549642805073, 4.727001020556933, 0.785]
# K[1] = [-1.2905204070967897 133.50213767263725 23.46305371477716; 39.41711323779116 -201.11117393475536 -141.60495677231867; -1.2905204070967913 133.50213767263733 23.463053714777168; 39.41711323779117 -201.11117393475539 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.5979255481115988, 0.04991231232465597, 0.08328253850728595]
# X_ref_window[1] = [4.0, 5.0, 0.785]
# K[1] = [-1.2905204070967897 133.50213767263725 23.46305371477716; 39.41711323779116 -201.11117393475536 -141.60495677231867; -1.2905204070967913 133.50213767263733 23.463053714777168; 39.41711323779117 -201.11117393475539 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [0.5979255481115988, 0.04991231232465597, 0.08328253850728595]
# X_ref_window[1] = [4.0, 5.0, 0.785]
# K[1] = [-1.2905204070967897 133.50213767263725 23.46305371477716; 39.41711323779116 -201.11117393475536 -141.60495677231867; -1.2905204070967913 133.50213767263733 23.463053714777168; 39.41711323779117 -201.11117393475539 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.166805986571155, 0.097400074980451, 0.1801292322473822]
# X_ref_window[1] = [3.9784225105700544, 5.2631578947368425, 0.785]
# K[1] = [-14.193512071716595 132.75176287120007 23.46305371477936; 58.67892546942029 -196.3573192573549 -141.60495677231913; -14.193512071716592 132.75176287120004 23.463053714779353; 58.678925469420314 -196.35731925735496 -141.60495677231913]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.1024222022152435, 0.19312460124925312, 0.3398024362136598]
# X_ref_window[1] = [3.9160227438402098, 5.526315789473684, 0.785]
# K[1] = [-35.11990363198647 128.8063612153283 23.463053714781392; 89.1524332670876 -184.52982631354487 -141.6049567723192; -35.11990363198647 128.80636121532822 23.463053714781385; 89.15243326708757 -184.52982631354482 -141.60495677231924]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [3.637545998021149, 0.3789437890240973, 0.6030590439537018]
# X_ref_window[1] = [3.8162997521504596, 5.7894736842105265, 0.785]
# K[1] = [-67.42874756542454 115.22955520536789 23.463053714784998; 134.10044289869057 -154.97252836961437 -141.6049567723216; -67.42874756542456 115.22955520536793 23.463053714785012; 134.10044289869057 -154.97252836961437 -141.60495677232166]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [6.146884844814622, 0.727782874282888, 1.037095812787069]
# X_ref_window[1] = [3.6827525878407927, 6.052631578947368, 0.785]
# K[1] = [-109.63470781698241 76.1886948941021 23.463053714781466; 186.83768408318323 -84.20862890342175 -141.60495677232257; -109.63470781698243 76.18869489410208 23.46305371478147; 186.83768408318318 -84.20862890342173 -141.60495677232254]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [10.226895332930866, 1.3562759043774868, 1.752701465828596]
# X_ref_window[1] = [3.5188803032512026, 6.315789473684211, 0.785]
# K[1] = [-132.72634637617134 -14.429244199067252 23.463053714776493; 196.25280133425616 59.02754504936 -141.60495677231899; -132.72634637617136 -14.429244199067261 23.46305371477651; 196.2528013342561 59.02754504935997 -141.60495677231893]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [16.828443333090835, 2.414747174727835, 2.9325357274314174]
# X_ref_window[1] = [3.3281819507216794, 6.578947368421052, 0.785]
# K[1] = [-37.238644095204855 -128.20986522929107 23.46305371477697; 20.214141439788698 203.93822954524876 -141.60495677231754; -37.23864409520484 -128.2098652292911 23.463053714776972; 20.214141439788694 203.93822954524876 -141.60495677231754]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [27.923080851471692, 3.9435510690664763, 4.792114491371734]
# X_ref_window[1] = [3.114156582592215, 6.842105263157895, 0.785]
# K[1] = [133.505883588453 0.8156424598227157 23.463053714777608; -201.25010910410623 -38.70150740391448 -141.6049567723189; 133.50588358845306 0.8156424598227164 23.463053714777615; -201.25010910410623 -38.70150740391448 -141.60495677231884]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [46.02291338864737, 6.682862602144758, 1.574856246842801]
# X_ref_window[1] = [2.8803032512027995, 7.105263157894736, 0.785]
# K[1] = [-133.18554367641192 9.278856376046235 23.463053714777384; 203.59985606460523 23.377589633877033 -141.6049567723188; -133.18554367641195 9.278856376046228 23.46305371477739; 203.59985606460526 23.377589633877037 -141.60495677231881]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [75.87821859929377, 11.199799146892909, 2.639318531997215]
# X_ref_window[1] = [2.630121008893425, 7.368421052631579, 0.785]
# K[1] = [-72.70621819490358 -111.97451451659079 23.4630537147716; 78.29638102061544 189.39136688472973 -141.6049567723194; -72.70621819490351 -111.97451451659066 23.463053714771586; 78.29638102061547 189.39136688472973 -141.6049567723194]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [124.94284209890174, 18.552783614238773, 4.394320143389362]
# X_ref_window[1] = [2.3671089080040826, 7.631578947368421, 0.785]
# K[1] = [123.39740216194178 -50.96633597263863 23.46305371477894; -200.52844911796117 42.281842265512054 -141.60495677231904; 123.39740216194176 -50.96633597263861 23.463053714778944; -200.52844911796115 42.281842265512054 -141.60495677231904]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [206.05272144537557, 30.760881699881125, 0.919004243959975]
# X_ref_window[1] = [2.0947660008747633, 7.894736842105264, 0.785]
# K[1] = [-99.89478914728504 88.57492614269667 23.463053714780994; 175.61518132814686 -105.6348482226934 -141.6049567723185; -99.89478914728505 88.57492614269664 23.463053714781005; 175.61518132814686 -105.6348482226934 -141.60495677231847]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [339.83367925534867, 50.860509925268765, 1.5580013844130178]
# X_ref_window[1] = [1.8165913398454587, 8.157894736842104, 0.785]
# K[1] = [-133.01023959052296 11.522256139532164 23.463053714777377; 203.96494417715127 19.94278399871988 -141.6049567723188; -133.01023959052299 11.522256139532168 23.463053714777363; 203.9649441771513 19.942783998719875 -141.6049567723188]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [560.2933390109519, 84.0364126128089, 2.6115295617945073]
# X_ref_window[1] = [1.5360839772561603, 8.421052631578947, 0.785]
# K[1] = [-75.78940469796379 -109.91111458078134 23.46305371479053; 83.52846539271604 187.14274883604466 -141.60495677231805; -75.78940469796379 -109.91111458078134 23.463053714790526; 83.52846539271602 187.14274883604463 -141.60495677231802]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [923.6108458927855, 138.64444694816896, 4.348503877125306]
# X_ref_window[1] = [1.2567429654468585, 8.68421052631579, 0.785]
# K[1] = [120.93364110088115 -56.56448331545671 23.463053714779875; -198.381499654511 51.42172327385447 -141.60495677231765; 120.93364110088113 -56.56448331545672 23.46305371477988; -198.38149965451098 51.421723273854475 -141.60495677231762]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [1522.8414890405331, 228.75577898699615, 0.8434659912263651]
# X_ref_window[1] = [0.9820673567575446, 8.947368421052632, 0.785]
# K[1] = [-92.92548816091795 95.86104344429603 23.46305371476739; 167.14250191202916 -118.5866661417039 -141.60495677232223; -92.9254881609179 95.86104344429604 23.46305371476739; 167.1425019120292 -118.58666614170394 -141.60495677232223]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2510.8619118328093, 377.2901823357345, 1.4334598603795932]
# X_ref_window[1] = [0.7155562035282115, 9.210526315789473, 0.785]
# K[1] = [-130.54874605806927 27.955521344336727 23.463053714778223; 204.86246828681678 -5.548167334107534 -141.6049567723187; -130.54874605806918 27.95552134433673 23.46305371477822; 204.86246828681675 -5.548167334107534 -141.60495677231873]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [4139.736306695133, 622.2262616688245, 2.4061953020351887]
# X_ref_window[1] = [0.4607085580988488, 9.473684210526315, 0.785]
# K[1] = [-96.6075491933082 -92.14916247294363 23.463053714787105; 119.93113406212737 166.18043340713695 -141.60495677232367; -96.60754919330817 -92.14916247294359 23.463053714787115; 119.93113406212737 166.18043340713697 -141.60495677232373]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [6825.136618606578, 1025.9995200333599, 4.009964915456653]
# X_ref_window[1] = [0.22102347280944779, 9.736842105263158, 0.785]
# K[1] = [95.28396802244437 -93.51712938726702 23.463053714816432; -170.04390798662024 114.3874193190887 -141.60495677230796; 95.28396802244434 -93.517129387267 23.463053714816425; -170.04390798662027 114.38741931908872 -141.60495677230796]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [11252.865260059183, 1691.7258608750217, 0.2853096041625216]
# X_ref_window[1] = [0.0, 10.0, 0.785]
# K[1] = [-28.052222682138247 130.52800107433316 23.46305371477918; 78.96952130009583 -189.11168054340823 -141.6049567723172; -28.052222682138254 130.5280010743332 23.463053714779186; 78.96952130009585 -189.1116805434082 -141.60495677231714]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [18553.012591297418, 2789.235529690018, 0.5132155526503005]
# X_ref_window[1] = [0.0, 10.0, 0.785]
# K[1] = [-56.81809051099762 120.81469816186352 23.463053714788238; 119.65503741388335 -166.3793406753019 -141.60495677231646; -56.81809051099765 120.81469816186356 23.46305371478825; 119.65503741388336 -166.3793406753019 -141.6049567723165]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [30588.90471927062, 4598.761120307022, 0.8889689376411893]
# X_ref_window[1] = [-0.22102347280944742, 10.263157894736842, 0.785]
# K[1] = [-97.18975855998109 91.53489559254962 23.463053714776198; 172.36367643708567 -110.8610669561893 -141.60495677231924; -97.18975855998104 91.53489559254963 23.463053714776198; 172.36367643708564 -110.8610669561893 -141.60495677231927]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [50432.69231906038, 7582.216294125618, 1.508481536013242]
# X_ref_window[1] = [-0.46070855809884825, 10.526315789473685, 0.785]
# K[1] = [-132.27684085619435 18.092086751393026 23.46305371477745; 204.7020723602054 9.822151398205953 -141.60495677231876; -132.27684085619433 18.092086751393026 23.463053714777452; 204.70207236020553 9.822151398205953 -141.6049567723188]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [83149.4638753199, 12501.142553594907, 2.529885134415951]
# X_ref_window[1] = [-0.715556203528211, 10.789473684210526, 0.785]
# K[1] = [-84.5006070297852 -103.36407948149669 23.46305371476358; 98.51242089655392 179.7073063138367 -141.60495677231702; -84.5006070297851 -103.36407948149663 23.463053714763557; 98.51242089655388 179.7073063138367 -141.60495677231702]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [137090.14104932072, 20611.003935729685, 4.213894973072148]
# X_ref_window[1] = [-0.9820673567575449, 11.052631578947368, 0.785]
# K[1] = [112.24855190673293 -72.28242327696233 23.46305371477662; -189.68598158794657 77.57990192142144 -141.6049567723147; 112.24855190673297 -72.28242327696232 23.463053714776628; -189.68598158794651 77.57990192142141 -141.6049567723147]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [226023.51838635825, 33981.96011909554, 0.6215334278882914]
# X_ref_window[1] = [-1.256742965446858, 11.31578947368421, 0.785]
# K[1] = [-69.54591483251922 113.96425730384908 23.463053714779974; 136.94041748919423 -152.46879967687173 -141.60495677231486; -69.5459148325192 113.9642573038491 23.463053714779978; 136.94041748919423 -152.46879967687173 -141.60495677231486]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [372649.93009898573, 56026.886224389775, 1.0675549225431076]
# X_ref_window[1] = [-1.5360839772561596, 11.578947368421053, 0.785]
# K[1] = [-111.90413486445509 72.81449552355448 23.46305371477925; 189.31554308250455 -78.47953928180473 -141.6049567723163; -111.90413486445506 72.81449552355447 23.463053714779253; 189.31554308250452 -78.47953928180472 -141.6049567723163]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [614395.9538697973, 92372.87815537082, 1.8029200479699665]
# X_ref_window[1] = [-1.8165913398454583, 11.842105263157894, 0.785]
# K[1] = [-131.8347090654422 -21.073581333058755 23.463053714781957; 193.04235398979446 68.80452522752337 -141.60495677231876; -131.8347090654422 -21.07358133305877 23.463053714781967; 193.0423539897945 68.80452522752338 -141.60495677231873]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.0129676359955218e6, 152297.30580228442, 3.0153321719922968]
# X_ref_window[1] = [-2.094766000874763, 12.105263157894736, 0.785]
# K[1] = [-26.50788016454108 -130.85036666550224 23.463053714776493; 3.278819832496591 204.91135260762005 -141.60495677231864; -26.507880164541092 -130.85036666550232 23.463053714776503; 3.278819832496592 204.91135260762007 -141.60495677231864]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.6701011078194242e6, 251095.83041698, 5.014261829722634]
# X_ref_window[1] = [-2.367108908004082, 12.368421052631579, 0.785]
# K[1] = [130.04548209372612 30.210243233268248 23.463053714779203; -187.77780882375703 -82.09084921919016 -141.60495677231714; 130.04548209372615 30.21024323326826 23.463053714779203; -187.77780882375708 -82.09084921919013 -141.60495677231714]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [2.7535311666843174e6, 413987.2100029832, 1.9411152888113463]
# X_ref_window[1] = [-2.630121008893424, 12.631578947368421, 0.785]
# K[1] = [-127.67481801728547 -39.03366455646241 23.463053714778173; 181.72371003954177 94.74125970939254 -141.60495677231782; -127.67481801728552 -39.03366455646241 23.463053714778177; 181.72371003954174 94.74125970939255 -141.60495677231782]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [4.539805338316211e6, 682549.6882406618, 3.243177605077007]
# X_ref_window[1] = [-2.8803032512027995, 12.894736842105264, 0.785]
# K[1] = [3.733579098459527 -133.4561597775368 23.463053714777914; -43.09112574682625 200.356102957607 -141.6049567723189; 3.733579098459527 -133.45615977753678 23.46305371477791; -43.09112574682626 200.35610295760705 -141.60495677231893]
# U_s[1] = [2.0, 2.0, 2.0, 2.0]
#
# X_s[1] = [7.484873373666546e6, 1.1253341635775384e6, 5.37163795161088]
# X_ref_window[1] = [-3.1141565825922144, 13.157894736842104, 0.785]
# K[1] = [111.26087161140187 73.79366256057376 23.463053714774812; -147.19681365125268 -142.59211291845523 -141.60495677231268; 111.26087161140191 73.79366256057378 23.4630537147748; -147.1968136512527 -142.5921129184552 -141.60495677231268]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [1.2340469828413393e7, 1.8553625157005936e6, 2.5303289026088187]
# X_ref_window[1] = [-3.328181950721679, 13.421052631578947, 0.785]
# K[1] = [-84.45472783243585 -103.40156638937368 23.463053714749655; 98.43266275583613 179.75100534269808 -141.60495677231734; -84.45472783243592 -103.40156638937363 23.463053714749663; 98.43266275583615 179.75100534269805 -141.60495677231734]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.0345994947802823e7, 3.0589757487288387e6, 4.2146266231309895]
# X_ref_window[1] = [-3.518880303251202, 13.68421052631579, 0.785]
# K[1] = [112.3014085579552 -72.20027821395797 23.463053714787822; -189.74269235130805 77.44109756277514 -141.60495677231611; 112.30140855795526 -72.20027821395799 23.463053714787826; -189.74269235130805 77.44109756277516 -141.60495677231614]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [3.3544874730718188e7, 5.043398543068352e6, 0.6227397149030116]
# X_ref_window[1] = [-3.682752587840793, 13.947368421052632, 0.785]
# K[1] = [-69.68333806423195 113.88028183652425 23.463053714778795; 137.12423964527093 -152.3035004657287 -141.6049567723214; -69.68333806423193 113.88028183652416 23.46305371477879; 137.12423964527093 -152.30350046572875 -141.6049567723214]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [5.5306148639035545e7, 8.315158560508822e6, 1.069543753602846]
# X_ref_window[1] = [-3.816299752150459, 14.210526315789473, 0.785]
# K[1] = [-112.04873197084727 72.59179465307258 23.463053714787574; 189.4712507283007 -78.10286750916562 -141.6049567723154; -112.04873197084726 72.59179465307257 23.463053714787556; 189.47125072830067 -78.1028675091656 -141.60495677231546]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [9.118442374895492e7, 1.3709378947235165e7, 1.8061990760419864]
# X_ref_window[1] = [-3.91602274384021, 14.473684210526315, 0.785]
# K[1] = [-131.76489867108063 -21.505756729750072 23.463053714773526; 192.81570464774424 69.43714552890566 -141.60495677231992; -131.7648986710807 -21.50575672975006 23.463053714773515; 192.81570464774427 69.43714552890567 -141.60495677231995]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.5033769894907486e8, 2.260294485500893e7, 3.0207383753218586]
# X_ref_window[1] = [-3.9784225105700535, 14.736842105263158, 0.785]
# K[1] = [-25.80009255279323 -130.9917607690931 23.463053714776745; 2.170984893459077 204.92608404959236 -141.604956772319; -25.80009255279323 -130.99176076909305 23.463053714776752; 2.1709848934590785 204.9260840495923 -141.60495677231899]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.478649618651538e8, 3.7265955984811276e7, 5.023175152145813]
# X_ref_window[1] = [-4.0, 15.0, 0.785]
# K[1] = [129.7710464098392 31.368164951302436 23.46305371477726; -187.03865698810733 -83.76129023496901 -141.60495677231634; 129.77104640983922 31.368164951302422 23.46305371477726; -187.0386569881073 -83.76129023496901 -141.60495677231637]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [4.086602348328143e8, 6.144117447805531e7, 1.955810873083049]
# X_ref_window[1] = [-4.0, 15.0, 0.785]
# K[1] = [-127.08743050511825 -40.90563815137406 23.463053714778376; 180.3118594970642 97.40146963982274 -141.60495677231674; -127.08743050511815 -40.90563815137403 23.46305371477834; 180.3118594970642 97.40146963982272 -141.6049567723167]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [6.737668215899575e8, 1.0129937142709437e8, 3.2674065274511293]
# X_ref_window[1] = [-3.9757982213150607, 15.266438256305584, 0.785]
# K[1] = [6.965665840175546 -133.32653780878508 23.463053714777523; -47.93241576493562 199.25334786452137 -141.60495677231899; 6.965665840175548 -133.32653780878508 23.463053714777537; -47.93241576493563 199.2533478645214 -141.604956772319]
# U_s[1] = [2.0, 2.0, 2.0, 2.0]
#
# X_s[1] = [1.1108536899956253e9, 1.6701442834856018e8, 5.4115846912952374]
# X_ref_window[1] = [-3.9061087622102346, 15.538708266511154, 0.785]
# K[1] = [108.22507918804624 78.17811897192634 23.46305371477278; -141.38481160988343 -148.3568282602656 -141.6049567723246; 108.22507918804627 78.17811897192635 23.46305371477278; -141.38481160988343 -148.35682826026564 -141.6049567723246]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [1.8314881072146213e9, 2.753602406711011e8, 2.5961899420215406]
# X_ref_window[1] = [-3.795305438110512, 15.81571657676046, 0.785]
# K[1] = [-77.46641485395823 -108.73564528849796 23.463053714769455; 86.38922450760973 185.83948725437511 -141.6049567723201; -77.46641485395823 -108.73564528849793 23.463053714769433; 86.38922450760975 185.83948725437514 -141.60495677232007]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [3.01961339924379e9, 4.539922859937697e8, 4.323213119721164]
# X_ref_window[1] = [-3.647762064440881, 16.09636973319726, 0.785]
# K[1] = [119.46456088178691 -59.60457163931577 23.463053714779107; -197.01770250809943 56.42196235220832 -141.60495677231762; 119.46456088178685 -59.6045716393158 23.4630537147791; -197.0177025080995 56.421962352208325 -141.60495677231765]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [4.978500840693269e9, 7.485067388197453e8, 0.8017685815420394]
# X_ref_window[1] = [-3.4678524566263302, 16.3795742819653, 0.785]
# K[1] = [-88.84871903777042 99.65135058173897 23.46305371478205; 162.05389521604044 -125.45097866103909 -141.6049567723185; -88.84871903777048 99.65135058173901 23.463053714782063; 162.05389521604044 -125.4509786610391 -141.60495677231845]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [8.20816023237577e9, 1.2340789816850114e9, 1.3647124540999478]
# X_ref_window[1] = [-3.25995043009185, 16.664236769208337, 0.785]
# K[1] = [-128.3200115658523 36.85730542794806 23.4630537147789; 203.99742593132362 -19.60773373160308 -141.6049567723179; -128.32001156585218 36.85730542794799 23.46305371477888; 203.9974259313236 -19.607733731603084 -141.6049567723179]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.3532968368470003e10, 2.034652267005812e9, 2.2928499909964737]
# X_ref_window[1] = [-3.0284298002624293, 16.949263741070126, 0.785]
# K[1] = [-106.40996997899121 -80.6312836012649 23.46305371476244; 137.9570387603981 151.54955817525732 -141.6049567723197; -106.40996997899128 -80.63128360126488 23.463053714762445; 137.95703876039806 151.5495581752573 -141.6049567723197]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.2312092804688465e10, 3.354574471227018e9, 3.823090090213001]
# X_ref_window[1] = [-2.777664382563056, 17.233561743694416, 0.785]
# K[1] = [76.25058048754964 -109.59167780002048 23.463053714793574; -145.83145691743917 143.98819131902337 -141.6049567723179; 76.25058048754961 -109.59167780002049 23.46305371479356; -145.8314569174392 143.98819131902343 -141.60495677231793]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [3.678642200106621e10, 5.530758284974033e9, 6.26039041200453]
# X_ref_window[1] = [-2.5120279924187203, 17.51603732322496, 0.785]
# K[1] = [12.851753986925889 132.8883691222987 23.46305371477737; 17.90218105741017 -204.15416968577534 -141.60495677231884; 12.851753986925893 132.88836912229877 23.463053714777388; 17.90218105741017 -204.15416968577532 -141.6049567723188]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [6.065055642592746e10, 9.118678827541788e9, 3.9956339884469045]
# X_ref_window[1] = [-2.2358944452544103, 17.79559702580551, 0.785]
# K[1] = [93.93403621869358 -94.8729821990951 23.463053714762378; -168.38722626086238 116.81247762539783 -141.60495677231748; 93.93403621869355 -94.8729821990951 23.463053714762374; -168.38722626086243 116.81247762539788 -141.60495677231754]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [9.999586245934425e10, 1.5034159743787985e10, 0.2616818999726984]
# X_ref_window[1] = [-1.9536375564951158, 18.07114739757982, 0.785]
# K[1] = [-24.960602572634002 131.15431655583382 23.46305371478233; 74.47962019572248 -190.92459075297506 -141.60495677231944; -24.960602572634016 131.15431655583393 23.46305371478234; 74.47962019572248 -190.9245907529751 -141.60495677231947]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.6486530541890076e11, 2.4787138956733826e10, 0.4742600541747285]
# X_ref_window[1] = [-1.669631141565826, 18.34159498469165, 0.785]
# K[1] = [-52.0697769607712 122.93585588299933 23.463053714775498; 113.08450793920859 -170.91315704353266 -141.6049567723206; -52.069776960771186 122.9358558829994 23.46305371477549; 113.08450793920854 -170.9131570435326 -141.60495677232055]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.7181693584477637e11, 4.086708323784979e10, 0.8247421786937874]
# X_ref_window[1] = [-1.38824901589153, 18.60584633328473, 0.785]
# K[1] = [-91.11441908911941 97.5840571324421 23.463053714756974; 164.89293910294683 -121.69524102891795 -141.6049567723188; -91.11441908911932 97.58405713244207 23.463053714756978; 164.89293910294688 -121.69524102891796 -141.60495677231884]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [4.4815036386393823e11, 6.7378429405849e10, 1.4025895123885306]
# X_ref_window[1] = [-1.1138649948972157, 18.86280798950284, 0.785]
# K[1] = [-129.623685874528 31.97164697660409 23.463053714778187; 204.59361470309696 -11.868695191952812 -141.604956772319; -129.62368587452795 31.97164697660408 23.46305371477818; 204.59361470309693 -11.868695191952812 -141.60495677231893]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [7.388750373745074e11, 1.1108824974796931e11, 2.3552987026684087]
# X_ref_window[1] = [-0.8508528940078727, 19.111386499489722, 0.785]
# K[1] = [-101.17049784509288 -87.11495735346413 23.463053714764563; 128.23019663120917 159.86378570243107 -141.6049567723216; -101.17049784509291 -87.11495735346412 23.46305371476457; 128.2301966312092 159.8637857024311 -141.6049567723216]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.2181989905085742e12, 1.831535602844537e11, 3.9260506094743395]
# X_ref_window[1] = [-0.6035865286484914, 19.350488409389122, 0.785]
# K[1] = [87.11046479367222 -101.1743693189103 23.463053714773924; -159.85808843252912 128.23729656084006 -141.6049567723126; 87.11046479367215 -101.17436931891017 23.463053714773903; -159.85808843252914 128.2372965608401 -141.6049567723126]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [2.0084705875970386e12, 3.0196917064556537e11, 0.14695830297344248]
# X_ref_window[1] = [-0.37643971424405953, 19.579020265344802, 0.785]
# K[1] = [-9.78301224121018 133.1494607080409 23.463053714777814; 52.13448554795795 -198.1953796535051 -141.60495677231924; -9.783012241210184 133.1494607080409 23.463053714777814; 52.13448554795794 -198.19537965350509 -141.60495677231918]
# U_s[1] = [-2.0, -2.0, -2.0, -2.0]
#
# X_s[1] = [3.311408179346572e12, 4.978629947389832e11, 0.2177512305561905]
# X_ref_window[1] = [-0.17378626621956628, 19.79588861350051, 0.785]
# K[1] = [-19.17667691771949 132.12396230212084 23.46305371478026; 66.02301501435359 -194.01127442459503 -141.60495677231893; -19.1766769177195 132.1239623021209 23.463053714780276; 66.0230150143536 -194.01127442459503 -141.6049567723189]
# U_s[1] = [-2.0, -2.0, -2.0, -2.0]
#
# X_s[1] = [5.45958910125883e12, 8.208373093205729e11, 0.33446903607700096]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-34.43243140498467 128.9918366882456 23.46305371477814; 88.16699858249468 -185.00268498894562 -141.60495677231938; -34.432431404984655 128.9918366882455 23.46305371477814; 88.16699858249464 -185.00268498894556 -141.60495677231935]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [9.001340680528201e12, 1.3533319316611487e12, 0.5942657537032374]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-66.41290764126285 115.81801404110666 23.463053714787275; 132.73255691213498 -156.14570504197428 -141.6049567723162; -66.4129076412628 115.81801404110661 23.463053714787268; 132.73255691213504 -156.14570504197428 -141.60495677231623]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.4840701844805363e13, 2.23126714204753e12, 1.0225981281116883]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-108.51866837591837 77.77008363058751 23.46305371480096; 185.59726093626477 -86.9083976888776 -141.60495677231594; -108.5186683759183 77.77008363058746 23.463053714800953; 185.59726093626483 -86.90839768887761 -141.604956772316]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.446818080364933e13, 3.6787375977082017e12, 1.7287988247283925]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-133.03329696153105 -11.252914281774643 23.463053714775906; 197.60752076987322 54.32016996753607 -141.60495677231904; -133.03329696153105 -11.252914281774641 23.4630537147759; 197.60752076987316 54.32016996753606 -141.60495677231904]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [4.034121014631317e13, 6.065212926665983e12, 2.893126934623601]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-42.26101928562005 -126.64316929865717 23.463053714775608; 28.23332610655217 202.98347834271195 -141.60495677232032; -42.26101928562006 -126.64316929865723 23.46305371477562; 28.233326106552177 202.98347834271192 -141.60495677232038]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [6.651141125401018e13, 9.999845563519629e12, 4.812779455481907]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [133.4605242386204 3.5741662323445236 23.463053714776553; -200.40743127629696 -42.85177442487321 -141.604956772319; 133.4605242386204 3.5741662323445276 23.463053714776557; -200.40743127629696 -42.85177442487321 -141.604956772319]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [1.0965877847877045e14, 1.6486958084291303e13, 1.608927012729498]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-133.4243256910895 4.736615753664236 23.463053714777526; 202.68535812904724 30.299483442135816 -141.60495677231881; -133.42432569108954 4.736615753664238 23.463053714777523; 202.68535812904727 30.29948344213582 -141.60495677231881]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.8079676059694228e14, 2.7182398482712688e13, 2.6954917284236566]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-66.30487955903733 -115.87989031047374 23.463053714775786; 67.53976012118711 193.48848573014587 -141.60495677232066; -66.30487955903732 -115.87989031047367 23.463053714775768; 67.53976012118713 193.48848573014584 -141.6049567723207]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.980834648698574e14, 4.4816198567095375e13, 4.486934087180853]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [127.5820183720149 -39.33592466793235 23.463053714778358; -203.57935551944934 23.555446294408327 -141.60495677231816; 127.5820183720149 -39.33592466793234 23.46305371477837; -203.5793555194494 23.555446294408338 -141.6049567723182]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [4.914565489749283e14, 7.388941984949092e13, 1.071698823052433]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-112.20491030913612 72.35015258430633 23.46305371478294; 189.6391292813008 -77.69436338759856 -141.6049567723239; -112.20491030913608 72.3501525843063 23.463053714782944; 189.63912928130082 -77.69436338759857 -141.60495677232393]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [8.102748659198438e14, 1.2182305818554811e14, 1.8097521848833562]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-131.6876559534318 -21.973795333398066 23.463053714780624; 192.567770336906 70.12180091729178 -141.60495677231938; -131.68765595343186 -21.97379533339807 23.46305371478064; 192.56777033690605 70.1218009172918 -141.60495677231938]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [1.3359174065557408e15, 2.0085226729225272e14, 3.0265964614457377]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-25.032293285274964 -131.1406518959072 23.46305371477888; 0.9704798509519622 204.9352855900016 -141.60495677231899; -25.032293285274978 -131.14065189590735 23.463053714778898; 0.9704798509519615 204.93528559000157 -141.604956772319]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.2025554440870005e15, 3.311494053530847e14, 5.032833503343845]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [129.4620343831103 32.62005710192668 23.463053714782856; -186.22094980253732 -85.56384042882854 -141.60495677231685; 129.4620343831104 32.62005710192669 23.463053714782863; -186.22094980253738 -85.56384042882853 -141.6049567723169]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [3.6314000105626045e15, 5.459730683853298e14, 1.9717348021431373]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-126.41996740900296 -42.924097860731415 23.46305371478307; 178.73805092522008 100.26027284195777 -141.6049567723197; -126.41996740900305 -42.92409786073144 23.463053714783072; 178.7380509252201 100.26027284195776 -141.60495677231972]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [5.987166439835236e15, 9.001574110763091e14, 3.2936606480056168]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [10.46323422813947 -133.09773443354428 23.463053714776695; -53.14651778354739 197.92640227438176 -141.604956772319; 10.463234228139472 -133.09773443354436 23.46305371477669; -53.146517783547374 197.92640227438167 -141.60495677231896]
# U_s[1] = [2.0, 2.0, 2.0, 2.0]
#
# X_s[1] = [9.871168660578312e15, 1.48410867061987e15, 5.454870418296946]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [104.74076447724151 82.78802810564136 23.463053714759646; -134.832650618402 -154.33589829736766 -141.6049567723204; 104.74076447724156 82.7880281056414 23.46305371475964; -134.832650618402 -154.3358982973677 -141.60495677232038]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [1.6274805737363956e16, 2.44688153328147e15, 2.6675560408469767]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-69.51577372429047 -113.98264740269578 23.463053714785456; 72.91793885167586 191.5264671514097 -141.60495677232296; -69.51577372429045 -113.98264740269573 23.463053714785442; 72.91793885167586 191.52646715140966 -141.60495677232294]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [2.683261839570444e16, 4.034225630804503e15, 4.4408759248615475]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [125.63561864153415 -45.16832525922462 23.463053714776695; -202.27892461722487 32.90364218516394 -141.60495677231862; 125.63561864153417 -45.16832525922459 23.463053714776695; -202.27892461722487 32.90364218516394 -141.60495677231862]
# U_s[1] = [-2.0, 2.0, -2.0, 2.0]
#
# X_s[1] = [4.423950869757746e16, 6.651313608311026e15, 0.9957617511472341]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-106.39277483148034 80.65397776156082 23.46305371478422; 183.1984063106618 -91.85726516045294 -141.60495677232214; -106.39277483148025 80.65397776156081 23.463053714784227; 183.19840631066185 -91.85726516045293 -141.60495677232214]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# X_s[1] = [7.293861899501928e16, 1.096616222411961e16, 1.6845531191985699]
# X_ref_window[1] = [0.0, 20.0, 0.785]
# K[1] = [-133.40083079415768 -5.357669592751876 23.463053714777928; 199.81677594617176 45.526576119073475 -141.6049567723187; -133.40083079415777 -5.357669592751883 23.463053714777956; 199.81677594617176 45.52657611907348 -141.6049567723187]
# U_s[1] = [2.0, -2.0, 2.0, -2.0]
#
# [5.45958910125883e12, 8.208373093205729e11, 0.33446903607700096]
